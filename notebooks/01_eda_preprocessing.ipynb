# %% [markdown]
# # Content Moderation — EDA & Preprocessing
#
# This notebook walks through data loading, label distribution analysis, and preprocessing for the moderation system.
#
# Run from project root:
# ```bash
# jupyter notebook notebooks/01_eda_preprocessing.ipynb
# ```

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
from src.dataset import prepare_data
from src.preprocessing import clean_text

# %%
train_df, val_df, test_df = prepare_data(source='demo', sample_size=2000)
print(f'Train: {len(train_df)}, Val: {len(val_df)}, Test: {len(test_df)}')

# %%
fig, ax = plt.subplots(figsize=(8, 4))
train_df['label'].value_counts().plot(kind='bar', ax=ax, color='steelblue')
ax.set_title('Label Distribution (Train Set)')
ax.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Preprocessing examples
samples = [
    "Check this out https://spam.com NOW!!!",
    "I won't tolerate this behavior.",
    "  Multiple   spaces   here  ",
]
for s in samples:
    print(f'  IN:  {s}')
    print(f'  OUT: {clean_text(s)}\n')
